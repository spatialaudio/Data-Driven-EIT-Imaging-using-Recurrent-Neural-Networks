# %%
import datetime
import os

import matplotlib.pyplot as plt
import numpy as np
from sciopy import plot_mesh
from pyeit.mesh.shape import thorax
import pyeit.mesh as mesh
import tensorflow as tf
from PIL import Image
from tqdm import tqdm
from sciopy import norm_data
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from support import GREIT_sample, show_mesh
from tensorflow import GradientTape, exp, keras, reduce_mean, reduce_sum, shape, square
from tensorflow.keras import layers, models
from tensorflow.keras.losses import Huber, binary_crossentropy, mse
from tensorflow.keras.metrics import Mean
from tensorflow.keras.models import Model
# Out:
# 2023-11-03 12:58:23.245635: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from IPython.display import IFrame
IFrame("../images/LSTM_VAE_V3.pdf", width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="../images/LSTM_VAE_V3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Data
# ![SegmentLocal](breathing.gif "segment")

# %%
tmp = np.load("../data_thorax/h0=0.025_n_el=16_r_min=0.1_r_max=0.4_dist_exc=8_step_meas=4noise=True/sample_000000.npz", allow_pickle=True)
tmp.files
# Out:
# ['anomaly',
#  'perm_array',
#  'n_el',
#  'h0',
#  'v_empty',
#  'v_obj',
#  'dist_exc',
#  'step_meas']

# %%
# create empty mesh:
mesh_obj = mesh.create(tmp["n_el"], h0=tmp["h0"], fd=thorax)

# %%
mesh_obj.perm = tmp["perm_array"]
plot_mesh(mesh_obj)

# %%
l_path = "../data_thorax/h0=0.025_n_el=16_r_min=0.1_r_max=0.4_dist_exc=8_step_meas=4noise=True/"
V_all = list()
radii = list()

for ele in tqdm(np.sort(os.listdir(l_path))):
    tmp_l = np.load(l_path +ele, allow_pickle=True)
    V_all.append(tmp_l["v_obj"])
    radii.append(tmp_l["anomaly"][0].r)
    
V_all = np.array(V_all)
radii = np.array(radii)
# Out:
# 100%|██████████| 10000/10000 [00:27<00:00, 363.73it/s]

# %%
print(V_all.shape, radii.shape)
# Out:
# (10000, 192) (10000,)

# %% [markdown]
# ## Build VAE

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 4

encoder_inputs = keras.Input(shape=(192,))

x = layers.Reshape((192,1))(encoder_inputs)
x = layers.Conv1D(64, activation="relu", kernel_size=3,strides=2, padding="same")(x)
x = layers.Conv1D(32, activation="relu", kernel_size=3,strides=2, padding="same")(x)
x = layers.Conv1D(16, activation="relu", kernel_size=3,strides=2, padding="same")(x)
x = layers.Conv1D(8, activation="relu", kernel_size=3,strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)

z = Sampling(name="z")([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# 2023-11-03 13:00:48.226538: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46672 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-03 13:00:48.228332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46672 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:81:00.0, compute capability: 8.6
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192)]        0           []
#
#  reshape (Reshape)              (None, 192, 1)       0           ['input_1[0][0]']
#
#  conv1d (Conv1D)                (None, 96, 64)       256         ['reshape[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 48, 32)       6176        ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 24, 16)       1552        ['conv1d_1[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 12, 8)        392         ['conv1d_2[0][0]']
#
#  flatten (Flatten)              (None, 96)           0           ['conv1d_3[0][0]']
#
#  dense (Dense)                  (None, 16)           1552        ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 4)            68          ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 4)            68          ['dense[0][0]']
#
#  z (Sampling)                   (None, 4)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 10,064
# Trainable params: 10,064
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Definiere den Decoder
latent_inputs = keras.Input(shape=(latent_dim,), name="z_sampling")
x = layers.Dense(16, activation="relu")(latent_inputs)
x = layers.Dense(96, activation="relu")(x)
x = layers.Reshape((12,8))(x)
x = layers.Conv1DTranspose(16, activation="relu", kernel_size=3, strides=2, padding="same")(x)
x = layers.Conv1DTranspose(32, activation="relu", kernel_size=3, strides=2, padding="same")(x)
x = layers.Conv1DTranspose(64, activation="relu", kernel_size=3, strides=2, padding="same")(x)
x = layers.Conv1DTranspose(128, activation="relu", kernel_size=3, strides=2, padding="same")(x)
x = layers.Conv1DTranspose(1, activation="relu", kernel_size=1, strides=1, padding="same")(x)

decoder_outputs = layers.Flatten()(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 4)]               0
#
#  dense_1 (Dense)             (None, 16)                80
#
#  dense_2 (Dense)             (None, 96)                1632
#
#  reshape_1 (Reshape)         (None, 12, 8)             0
#
#  conv1d_transpose (Conv1DTra  (None, 24, 16)           400
#  nspose)
#
#  conv1d_transpose_1 (Conv1DT  (None, 48, 32)           1568
#  ranspose)
#
#  conv1d_transpose_2 (Conv1DT  (None, 96, 64)           6208
#  ranspose)
#
#  conv1d_transpose_3 (Conv1DT  (None, 192, 128)         24704
#  ranspose)
#
#  conv1d_transpose_4 (Conv1DT  (None, 192, 1)           129
#  ranspose)
#
#  flatten_1 (Flatten)         (None, 192)               0
#
# =================================================================
# Total params: 34,721
# Trainable params: 34,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)

            # mse_loss = tf.keras.losses.mean_squared_error(data, reconstruction)
            mse_loss = tf.keras.losses.mean_squared_error(data, reconstruction)
            reconstruction_loss = tf.reduce_mean(mse_loss)

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())

# %%
#V_all = np.expand_dims(V_all,2)

V_vae_train, V_vae_test = train_test_split(
    V_all, test_size=0.05, shuffle=True, random_state=52
)

# %%
print(V_vae_train.shape, V_vae_test.shape)
print(np.min(V_all), np.max(V_all))
# Out:
# (9500, 192) (500, 192)
# -0.6822878622665547 0.6822878622665547

# %%
history = vae.fit(V_vae_train, epochs=25, batch_size=64)
# Out:
# Epoch 1/25
# 2023-11-03 13:00:52.704418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-11-03 13:00:53.481475: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-03 13:00:53.941949: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x56449610de30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-03 13:00:53.942037: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-11-03 13:00:53.942060: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-11-03 13:00:53.979445: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-03 13:00:54.176540: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 149/149 [==============================] - 9s 12ms/step - loss: 0.0549 - reconstruction_loss: 0.0454 - kl_loss: 2.3241e-06
# Epoch 2/25
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0387 - reconstruction_loss: 0.0387 - kl_loss: 3.2002e-08
# Epoch 3/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0386 - reconstruction_loss: 0.0386 - kl_loss: 2.5402e-08
# Epoch 4/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0386 - reconstruction_loss: 0.0387 - kl_loss: 2.8002e-08
# Epoch 5/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0387 - reconstruction_loss: 0.0386 - kl_loss: 2.1202e-08
# Epoch 6/25
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0389 - reconstruction_loss: 0.0386 - kl_loss: 1.7601e-08
# Epoch 7/25
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0384 - reconstruction_loss: 0.0386 - kl_loss: 2.3002e-08
# Epoch 8/25
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0384 - reconstruction_loss: 0.0386 - kl_loss: 2.7802e-08
# Epoch 9/25
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0388 - reconstruction_loss: 0.0386 - kl_loss: 2.2202e-08
# Epoch 10/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0386 - reconstruction_loss: 0.0385 - kl_loss: 2.4602e-08
# Epoch 11/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0384 - reconstruction_loss: 0.0385 - kl_loss: 2.2802e-08
# Epoch 12/25
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0382 - reconstruction_loss: 0.0385 - kl_loss: 1.9001e-08
# Epoch 13/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0384 - reconstruction_loss: 0.0385 - kl_loss: 1.3201e-08
# Epoch 14/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0388 - reconstruction_loss: 0.0385 - kl_loss: 2.2002e-08
# Epoch 15/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0382 - reconstruction_loss: 0.0385 - kl_loss: 1.6001e-08
# Epoch 16/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0384 - reconstruction_loss: 0.0385 - kl_loss: 2.0202e-08
# Epoch 17/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0386 - reconstruction_loss: 0.0385 - kl_loss: 1.9402e-08
# Epoch 18/25
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0386 - reconstruction_loss: 0.0385 - kl_loss: 2.1402e-08
# Epoch 19/25
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0384 - reconstruction_loss: 0.0385 - kl_loss: 2.6802e-08
# Epoch 20/25
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0384 - reconstruction_loss: 0.0385 - kl_loss: 2.0002e-08
# Epoch 21/25
# 149/149 [==============================] - 1s 7ms/step - loss: 0.0388 - reconstruction_loss: 0.0385 - kl_loss: 2.2002e-08
# Epoch 22/25
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0383 - reconstruction_loss: 0.0385 - kl_loss: 2.4802e-08
# Epoch 23/25
# 149/149 [==============================] - 1s 8ms/step - loss: 0.0384 - reconstruction_loss: 0.0385 - kl_loss: 2.8802e-08
# Epoch 24/25
# 149/149 [==============================] - 1s 7ms/step - loss: 0.0383 - reconstruction_loss: 0.0385 - kl_loss: 1.9802e-08
# Epoch 25/25
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0383 - reconstruction_loss: 0.0385 - kl_loss: 2.1402e-08

# %%
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["reconstruction_loss"], label="reconstruction_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
z_mean, _, _ = vae.encoder.predict(V_all)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.figure(figsize=(8, 6))
plt.scatter(z_mean[:, 0], z_mean[:, 1], c=radii, s =10)
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.colorbar(label="lung wing radius")
plt.show()

# %%
# Perform t-SNE to reduce the dimensionality to 2D
tsne = TSNE(n_components=2)
latent_space_2d = tsne.fit_transform(z_mean) # latent data

# %%
plt.figure(figsize=(8, 6))
plt.title("latent space")
plt.scatter(latent_space_2d[:,0],latent_space_2d[:,1], c=radii)
plt.xlabel("latent dimention 1")
plt.ylabel("latent dimention 2")
plt.colorbar(label="lung wing radius")
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build LSTM

# %%
_,_, V_z_all = vae.encoder.predict(V_all)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
nseg = 3

X = [V_z_all[n : n + nseg, :] for n in range(V_z_all.shape[0] - nseg + 1)]
X = np.array(X)

Y = np.array(V_z_all[nseg - 1 :])

# %%
print(X.shape, Y.shape)
# Out:
# (9998, 3, 4) (9998, 4)

# %%
def lstm_split(input_shape, nseg, v_shape):
    def Slice(s):
        def func(x):
            return x[:, s, :]

        return func

    # define shared layers
    dense = Dense(v_shape, activation="relu")
    inputs = Input(shape=input_shape)
    con_list = []
    for s in range(nseg):
        # slicing x
        x = Lambda(Slice(s))(inputs)
        # shared layers
        x = dense(x)
        con_list.append(x)

    # concat and reshape for LSTM
    x = Concatenate(axis=1)(con_list)
    x = Reshape((nseg, int(x.shape[1] / nseg)))(x)

    x = LSTM(v_shape)(x)
    x = Activation("softmax")(x)

    return Model(inputs, x)

# %%
lstm = lstm_split(
    input_shape=(nseg, latent_dim), nseg=nseg, v_shape=V_z_all.shape[1]
)
lstm.compile(optimizer="adam", loss="binary_crossentropy")
print(lstm.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 lstm = lstm_split(
#       2     input_shape=(nseg, latent_dim), nseg=nseg, v_shape=V_z_all.shape[1]
#       3 )
#       4 lstm.compile(optimizer="adam", loss="binary_crossentropy")
#       5 print(lstm.summary())
#
# Cell In[27], line 10, in lstm_split(input_shape, nseg, v_shape)
#       8 # define shared layers
#       9 dense = layers.Dense(v_shape, activation="relu")
# ---> 10 inputs = Input(shape=input_shape)
#      11 con_list = []
#      12 for s in range(nseg):
#      13     # slicing x
#
# NameError: name 'Input' is not defined

# %%
X_lstm_train, X_lstm_test, Y_lstm_train, Y_lstm_test = train_test_split(
    X, Y, test_size=0.05, shuffle=True, random_state=52
)

# %%
epochs = 100
batch_size = 8

history = lstm.fit(
    X_lstm_train,
    Y_lstm_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_lstm_test, Y_lstm_test),
)

# %%
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
plt.show()

# %%
pred = lstm.predict(X)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(pred[:, 1], pred[:, 2], s =10)
plt.xlabel("z[0]")
plt.ylabel("z[1]")
#plt.colorbar(label="lung wing radius")
plt.show()

# %%
# Perform t-SNE to reduce the dimensionality to 2D
tsne = TSNE(n_components=2)
latent_space_2d = tsne.fit_transform(pred) # latent data

# %%
plt.figure(figsize=(8, 6))
plt.title("latent space")
plt.scatter(latent_space_2d[:,0],latent_space_2d[:,1], c=radii[nseg - 1 :])
plt.xlabel("latent dimention 1")
plt.ylabel("latent dimention 2")
plt.colorbar(label="lung wing radius")
plt.grid()
plt.tight_layout()
plt.show()

# %%
vae.decoder.predict(pred).shape
# Out:
# 16/16 [==============================] - 0s 3ms/step
# (500, 192)

# %%
plt.stem(vae.decoder.predict(pred)[10,:])
# Out:
# 16/16 [==============================] - 0s 3ms/step
# <StemContainer object of 3 artists>

# %%
plt.stem(vae.decoder.predict(Y_lstm_test)[10,:])
# Out:
# 16/16 [==============================] - 0s 2ms/step
# <StemContainer object of 3 artists>
