# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import GradientTape, exp, keras, reduce_mean, reduce_sum, shape, square
from tensorflow.keras import layers, models
from tensorflow.keras.layers import (
    LSTM,
    Activation,
    Add,
    BatchNormalization,
    Bidirectional,
    Concatenate,
    Conv1D,
    Conv2D,
    ConvLSTM1D,
    Cropping1D,
    Cropping2D,
    Dense,
    Dropout,
    Flatten,
    Input,
    Lambda,
    MaxPooling1D,
    Normalization,
    Reshape,
    ZeroPadding1D,
)
from tensorflow.keras.losses import Huber, binary_crossentropy, mse
from tensorflow.keras.metrics import Mean
from tensorflow.keras.models import Model
# Out:
# 2023-10-13 08:44:11.417958: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-13 08:44:12.584636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
n_el = 16
r_obj = 0.4
dist_exc = 8
step_meas = 1

load_path = f"data/{n_el=}_{r_obj=}_{dist_exc=}_{step_meas=}/"

if os.path.isdir(load_path):
    print("This directory exists...continue")
else:
    print("You have to generate the data...")
# Out:
# You have to generate the data...

# %%
V = np.load("saves/" + load_path.split("/")[1] + "_v_data.npy", allow_pickle=True)

# %%
V.shape
# Out:
# (499, 192)

# %%
latent_dim = 10
nseg = 4

# channels = [8, 4, 1, 1]
# strides = [1, 2, 1, 10]
kernel_size = 4


def encoder_model(latent_dim=10, nseg=4, kernel_size=4):
    def sampling(args):
        z_mean, z_log_var = args
        epsilon = keras.backend.random_normal(
            shape=(keras.backend.shape(z_mean)[0], latent_dim)
        )
        return z_mean + keras.backend.exp(0.5 * z_log_var) * epsilon

    def slice_enconder(s):
        def func(x):
            return x[:, s, :, :]

        return func

    def slice_lstm(s):
        def func(x):
            return x[:, s, :]

        return func

    # start encoder model
    encoder_inputs = keras.Input(shape=(nseg, 192, 1))
    inputs = tf.keras.layers.ZeroPadding2D(padding=((0, 4)))(encoder_inputs)
    print(inputs.shape)

    # Build conv layers for wheight sharing
    conv1d_l1 = Conv1D(8, kernel_size=kernel_size, padding="same", strides=1)
    conv1d_l2 = Conv1D(4, kernel_size=kernel_size, padding="same", strides=2)
    conv1d_l3 = Conv1D(1, kernel_size=kernel_size, padding="same", strides=1)
    conv1d_l4 = Conv1D(1, kernel_size=kernel_size, padding="same", strides=10)

    z_mean_list = list()
    z_var_list = list()
    for s in range(nseg):
        x = Lambda(slice_enconder(s))(inputs)
        x = conv1d_l1(x)
        x = conv1d_l2(x)
        x = conv1d_l3(x)
        x = conv1d_l4(x)
        # x = conv1d(ch_n, kernel_size=kernel_size, padding='same', strides=str_n)(x)
        # x = Conv1D(ch_n, kernel_size=kernel_size, padding='same', strides=str_n)(x)
        # x = BatchNormalization()(x)
        # x = Activation("relu")(x)
        x = Flatten()(x)

        z_mean = layers.Dense(latent_dim, name=f"z_mean_{s}")(x)
        z_log_var = layers.Dense(latent_dim, name=f"z_log_var_{s}")(x)

        z_mean_list.append(z_mean)
        z_var_list.append(z_log_var)

    z_mean = Concatenate(axis=1)(z_mean_list)
    z_mean = Reshape((nseg, int(z_mean.shape[1] / nseg)))(z_mean)

    z_var = Concatenate(axis=1)(z_var_list)
    z_var = Reshape((nseg, int(z_var.shape[1] / nseg)))(z_var)

    # hier LSTMs
    ### mean block
    lstm_list_mean = list()
    for s in range(nseg):
        lstm_mean = Lambda(slice_lstm(s))(z_mean)
        lstm_mean = Dense(10, activation="relu")(lstm_mean)
        lstm_list_mean.append(lstm_mean)
    # concat and reshape for LSTM
    lstm_mean = Concatenate(axis=1)(lstm_list_mean)
    lstm_mean = Reshape((nseg, int(lstm_mean.shape[1] / nseg)))(lstm_mean)
    lstm_mean = LSTM(latent_dim)(lstm_mean)
    lstm_mean = Activation("softmax")(lstm_mean)
    ### mean block

    ### var block
    lstm_list_var = list()
    for s in range(nseg):
        lstm_var = Lambda(slice_lstm(s))(z_var)
        lstm_var = Dense(10, activation="relu")(lstm_var)
        lstm_list_var.append(lstm_var)
    # concat and reshape for LSTM
    lstm_var = Concatenate(axis=1)(lstm_list_var)
    lstm_var = Reshape((nseg, int(lstm_var.shape[1] / nseg)))(lstm_var)
    lstm_var = LSTM(latent_dim)(lstm_var)
    lstm_var = Activation("softmax")(lstm_var)
    ### var block
    # end LSTM

    z = layers.Lambda(sampling, output_shape=(latent_dim,), name="z")(
        [lstm_mean, lstm_var]
    )

    return encoder_inputs, lstm_mean, lstm_var, z


# encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
# encoder.summary()

# %%
def decoder_model(latent_dim=latent_dim):
    latent_inputs = keras.Input(shape=(latent_dim,), name="z_sampling")
    x = layers.Dense(100, activation="relu")(latent_inputs)
    x = Reshape((100, 1))(x)
    x = layers.Dense(2, activation="relu")(x)
    x = layers.Flatten()(x)
    x = Reshape((200, 1))(x)
    decoder_outputs = Cropping1D(cropping=(0, 8))(x)
    return latent_inputs, decoder_outputs


# decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
# decoder.summary()

# %%
def vae_model():
    encoder_inputs, z_mean, z_log_var, z = encoder_model()
    encoder = Model(encoder_inputs, (z_mean, z_log_var, z), name="VAE_encoder")
    encoder.summary()

    decoder_inputs, decoder_outputs = decoder_model()
    decoder = Model(decoder_inputs, decoder_outputs, name="VAE_decoder")
    decoder.summary()

    return VAE(encoder, decoder)

# %%
# creates overlapping segments with a length of nseg
X0 = [V[n : n + nseg, :] for n in range(V.shape[0] - nseg + 1)]  # is this nseg+1 right?
X0 = np.array(X0)

Y0 = np.array(V[nseg - 1 :])  # is this -1 right?

# %%
# proof that the shift is right
print(np.allclose(X0[0], V[0:nseg, :]))
print(np.allclose(X0[244], V[244 : 244 + nseg, :]))
# Out:
# True
# True

# %%
class VAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = Mean(name="total_loss")
        self.reconstruction_loss_tracker = Mean(name="reconstruction_loss")
        self.kl_loss_tracker = Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)[0]
            print(data[0,0,:].shape, reconstruction[0].shape)
            reconstruction_loss = reduce_mean(reduce_sum(binary_crossentropy(data[0,0,:], reconstruction, axis=1)))
            kl_loss = -0.5 * (1 + z_log_var - square(z_mean) - exp(z_log_var))
            kl_loss = reduce_mean(reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstruction = self.decoder(z)[0]
        reconstruction_loss = reduce_mean(binary_crossentropy(inputs, reconstruction))
        reconstruction_loss *= 192
        kl_loss = 1 + z_log_var - square(z_mean) - exp(z_log_var)
        kl_loss = reduce_mean(kl_loss)
        kl_loss *= -0.5
        total_loss = reconstruction_loss + kl_loss
        self.add_metric(kl_loss, name='kl_loss', aggregation='mean')
        self.add_metric(total_loss, name='total_loss', aggregation='mean')
        self.add_metric(reconstruction_loss, name='reconstruction_loss', aggregation='mean')
        return reconstruction

# %%
vae = vae_model()
# Out:
# (None, 4, 200, 1)
# 2023-10-13 08:44:31.108924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 44477 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:5f:00.0, compute capability: 8.6
# 2023-10-13 08:44:31.111647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46672 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:d8:00.0, compute capability: 8.6
# 2023-10-13 08:44:32.714802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-13 08:44:32.715989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-13 08:44:32.717284: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-13 08:44:32.907701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-13 08:44:32.908862: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-13 08:44:32.909973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "VAE_encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4, 192, 1)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 4, 200, 1)   0           ['input_1[0][0]']
#
#  lambda (Lambda)                (None, 200, 1)       0           ['zero_padding2d[0][0]']
#
#  lambda_1 (Lambda)              (None, 200, 1)       0           ['zero_padding2d[0][0]']
#
#  lambda_2 (Lambda)              (None, 200, 1)       0           ['zero_padding2d[0][0]']
#
#  lambda_3 (Lambda)              (None, 200, 1)       0           ['zero_padding2d[0][0]']
#
#  conv1d (Conv1D)                (None, 200, 8)       40          ['lambda[0][0]',
#                                                                   'lambda_1[0][0]',
#                                                                   'lambda_2[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 100, 4)       132         ['conv1d[0][0]',
#                                                                   'conv1d[1][0]',
#                                                                   'conv1d[2][0]',
#                                                                   'conv1d[3][0]']
#
#  conv1d_2 (Conv1D)              (None, 100, 1)       17          ['conv1d_1[0][0]',
#                                                                   'conv1d_1[1][0]',
#                                                                   'conv1d_1[2][0]',
#                                                                   'conv1d_1[3][0]']
#
#  conv1d_3 (Conv1D)              (None, 10, 1)        5           ['conv1d_2[0][0]',
#                                                                   'conv1d_2[1][0]',
#                                                                   'conv1d_2[2][0]',
#                                                                   'conv1d_2[3][0]']
#
#  flatten (Flatten)              (None, 10)           0           ['conv1d_3[0][0]']
#
#  flatten_1 (Flatten)            (None, 10)           0           ['conv1d_3[1][0]']
#
#  flatten_2 (Flatten)            (None, 10)           0           ['conv1d_3[2][0]']
#
#  flatten_3 (Flatten)            (None, 10)           0           ['conv1d_3[3][0]']
#
#  z_mean_0 (Dense)               (None, 10)           110         ['flatten[0][0]']
#
#  z_mean_1 (Dense)               (None, 10)           110         ['flatten_1[0][0]']
#
#  z_mean_2 (Dense)               (None, 10)           110         ['flatten_2[0][0]']
#
#  z_mean_3 (Dense)               (None, 10)           110         ['flatten_3[0][0]']
#
#  z_log_var_0 (Dense)            (None, 10)           110         ['flatten[0][0]']
#
#  z_log_var_1 (Dense)            (None, 10)           110         ['flatten_1[0][0]']
#
#  z_log_var_2 (Dense)            (None, 10)           110         ['flatten_2[0][0]']
#
#  z_log_var_3 (Dense)            (None, 10)           110         ['flatten_3[0][0]']
#
#  concatenate (Concatenate)      (None, 40)           0           ['z_mean_0[0][0]',
#                                                                   'z_mean_1[0][0]',
#                                                                   'z_mean_2[0][0]',
#                                                                   'z_mean_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 40)           0           ['z_log_var_0[0][0]',
#                                                                   'z_log_var_1[0][0]',
#                                                                   'z_log_var_2[0][0]',
#                                                                   'z_log_var_3[0][0]']
#
#  reshape (Reshape)              (None, 4, 10)        0           ['concatenate[0][0]']
#
#  reshape_1 (Reshape)            (None, 4, 10)        0           ['concatenate_1[0][0]']
#
#  lambda_4 (Lambda)              (None, 10)           0           ['reshape[0][0]']
#
#  lambda_5 (Lambda)              (None, 10)           0           ['reshape[0][0]']
#
#  lambda_6 (Lambda)              (None, 10)           0           ['reshape[0][0]']
#
#  lambda_7 (Lambda)              (None, 10)           0           ['reshape[0][0]']
#
#  lambda_8 (Lambda)              (None, 10)           0           ['reshape_1[0][0]']
#
#  lambda_9 (Lambda)              (None, 10)           0           ['reshape_1[0][0]']
#
#  lambda_10 (Lambda)             (None, 10)           0           ['reshape_1[0][0]']
#
#  lambda_11 (Lambda)             (None, 10)           0           ['reshape_1[0][0]']
#
#  dense (Dense)                  (None, 10)           110         ['lambda_4[0][0]']
#
#  dense_1 (Dense)                (None, 10)           110         ['lambda_5[0][0]']
#
#  dense_2 (Dense)                (None, 10)           110         ['lambda_6[0][0]']
#
#  dense_3 (Dense)                (None, 10)           110         ['lambda_7[0][0]']
#
#  dense_4 (Dense)                (None, 10)           110         ['lambda_8[0][0]']
#
#  dense_5 (Dense)                (None, 10)           110         ['lambda_9[0][0]']
#
#  dense_6 (Dense)                (None, 10)           110         ['lambda_10[0][0]']
#
#  dense_7 (Dense)                (None, 10)           110         ['lambda_11[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 40)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]',
#                                                                   'dense_2[0][0]',
#                                                                   'dense_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 40)           0           ['dense_4[0][0]',
#                                                                   'dense_5[0][0]',
#                                                                   'dense_6[0][0]',
#                                                                   'dense_7[0][0]']
#
#  reshape_2 (Reshape)            (None, 4, 10)        0           ['concatenate_2[0][0]']
#
#  reshape_3 (Reshape)            (None, 4, 10)        0           ['concatenate_3[0][0]']
#
#  lstm (LSTM)                    (None, 10)           840         ['reshape_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 10)           840         ['reshape_3[0][0]']
#
#  activation (Activation)        (None, 10)           0           ['lstm[0][0]']
#
#  activation_1 (Activation)      (None, 10)           0           ['lstm_1[0][0]']
#
#  z (Lambda)                     (None, 10)           0           ['activation[0][0]',
#                                                                   'activation_1[0][0]']
#
# ==================================================================================================
# Total params: 3,634
# Trainable params: 3,634
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "VAE_decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling (InputLayer)     [(None, 10)]              0
#
#  dense_8 (Dense)             (None, 100)               1100
#
#  reshape_4 (Reshape)         (None, 100, 1)            0
#
#  dense_9 (Dense)             (None, 100, 2)            4
#
#  flatten_4 (Flatten)         (None, 200)               0
#
#  reshape_5 (Reshape)         (None, 200, 1)            0
#
#  cropping1d (Cropping1D)     (None, 192, 1)            0
#
# =================================================================
# Total params: 1,104
# Trainable params: 1,104
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.compile(optimizer="adam", loss="MeanSquaredError")

# %%
history = vae.fit(x=X0, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 24ms/step - loss: 231.6573 - reconstruction_loss: 234.2290 - kl_loss: 0.0761
# Epoch 2/100
# 16/16 [==============================] - 0s 24ms/step - loss: 232.0782 - reconstruction_loss: 222.9086 - kl_loss: 0.0761
# Epoch 3/100
# 16/16 [==============================] - 0s 24ms/step - loss: 253.6599 - reconstruction_loss: 242.8130 - kl_loss: 0.0761
# Epoch 4/100
# 16/16 [==============================] - 0s 24ms/step - loss: 246.9724 - reconstruction_loss: 237.4569 - kl_loss: 0.0760
# Epoch 5/100
# 16/16 [==============================] - 0s 23ms/step - loss: 234.5275 - reconstruction_loss: 237.0456 - kl_loss: 0.0760
# Epoch 6/100
# 16/16 [==============================] - 0s 23ms/step - loss: 248.7679 - reconstruction_loss: 241.3625 - kl_loss: 0.0759
# Epoch 7/100
# 16/16 [==============================] - 0s 24ms/step - loss: 224.9342 - reconstruction_loss: 214.9847 - kl_loss: 0.0759
# Epoch 8/100
# 16/16 [==============================] - 0s 24ms/step - loss: 222.7351 - reconstruction_loss: 222.6499 - kl_loss: 0.0759
# Epoch 9/100
# 16/16 [==============================] - 0s 23ms/step - loss: 218.6550 - reconstruction_loss: 211.0284 - kl_loss: 0.0759
# Epoch 10/100
# 16/16 [==============================] - 0s 24ms/step - loss: 220.0027 - reconstruction_loss: 212.9156 - kl_loss: 0.0759
# Epoch 11/100
# 16/16 [==============================] - 0s 23ms/step - loss: 213.7398 - reconstruction_loss: 216.0777 - kl_loss: 0.0759
# Epoch 12/100
# 16/16 [==============================] - 0s 23ms/step - loss: 210.3914 - reconstruction_loss: 208.5150 - kl_loss: 0.0759
# Epoch 13/100
# 16/16 [==============================] - 0s 24ms/step - loss: 218.8667 - reconstruction_loss: 214.5715 - kl_loss: 0.0759
# Epoch 14/100
# 16/16 [==============================] - 0s 23ms/step - loss: 227.5846 - reconstruction_loss: 220.9311 - kl_loss: 0.0760
# Epoch 15/100
# 16/16 [==============================] - 0s 22ms/step - loss: 206.7500 - reconstruction_loss: 204.9651 - kl_loss: 0.0760
# Epoch 16/100
# 16/16 [==============================] - 0s 24ms/step - loss: 210.4860 - reconstruction_loss: 207.1541 - kl_loss: 0.0760
# Epoch 17/100
# 16/16 [==============================] - 0s 23ms/step - loss: 209.5845 - reconstruction_loss: 213.3522 - kl_loss: 0.0760
# Epoch 18/100
# 16/16 [==============================] - 0s 23ms/step - loss: 208.2019 - reconstruction_loss: 207.7903 - kl_loss: 0.0762
# Epoch 19/100
# 16/16 [==============================] - 0s 23ms/step - loss: 205.0505 - reconstruction_loss: 208.3528 - kl_loss: 0.0764
# Epoch 20/100
# 16/16 [==============================] - 0s 24ms/step - loss: 192.6300 - reconstruction_loss: 191.6012 - kl_loss: 0.0765
# Epoch 21/100
# 16/16 [==============================] - 0s 24ms/step - loss: 191.9598 - reconstruction_loss: 197.3649 - kl_loss: 0.0765
# Epoch 22/100
# 16/16 [==============================] - 0s 24ms/step - loss: 192.1647 - reconstruction_loss: 201.4955 - kl_loss: 0.0765
# Epoch 23/100
# 16/16 [==============================] - 0s 24ms/step - loss: 187.5732 - reconstruction_loss: 189.2915 - kl_loss: 0.0765
# Epoch 24/100
# 16/16 [==============================] - 0s 24ms/step - loss: 189.3859 - reconstruction_loss: 188.8822 - kl_loss: 0.0765
# Epoch 25/100
# 16/16 [==============================] - 0s 24ms/step - loss: 183.4092 - reconstruction_loss: 183.6703 - kl_loss: 0.0765
# Epoch 26/100
# 16/16 [==============================] - 0s 24ms/step - loss: 193.0141 - reconstruction_loss: 204.1570 - kl_loss: 0.0765
# Epoch 27/100
# 16/16 [==============================] - 0s 24ms/step - loss: 192.7744 - reconstruction_loss: 196.7681 - kl_loss: 0.0764
# Epoch 28/100
# 16/16 [==============================] - 0s 24ms/step - loss: 192.0802 - reconstruction_loss: 193.6086 - kl_loss: 0.0764
# Epoch 29/100
# 16/16 [==============================] - 0s 24ms/step - loss: 195.4837 - reconstruction_loss: 191.5509 - kl_loss: 0.0763
# Epoch 30/100
# 16/16 [==============================] - 0s 23ms/step - loss: 194.1616 - reconstruction_loss: 193.6447 - kl_loss: 0.0763
# Epoch 31/100
# 16/16 [==============================] - 0s 24ms/step - loss: 183.8490 - reconstruction_loss: 184.3418 - kl_loss: 0.0768
# Epoch 32/100
# 16/16 [==============================] - 0s 24ms/step - loss: 183.5469 - reconstruction_loss: 188.1832 - kl_loss: 0.0773
# Epoch 33/100
# 16/16 [==============================] - 0s 23ms/step - loss: 182.7679 - reconstruction_loss: 183.3532 - kl_loss: 0.0795
# Epoch 34/100
# 16/16 [==============================] - 0s 23ms/step - loss: 175.6119 - reconstruction_loss: 178.5245 - kl_loss: 0.0830
# Epoch 35/100
# 16/16 [==============================] - 0s 24ms/step - loss: 182.2842 - reconstruction_loss: 180.1028 - kl_loss: 0.0840
# Epoch 36/100
# 16/16 [==============================] - 0s 22ms/step - loss: 171.7907 - reconstruction_loss: 177.8244 - kl_loss: 0.0846
# Epoch 37/100
# 16/16 [==============================] - 0s 23ms/step - loss: 178.3823 - reconstruction_loss: 179.6610 - kl_loss: 0.0845
# Epoch 38/100
# 16/16 [==============================] - 0s 24ms/step - loss: 181.3309 - reconstruction_loss: 180.1646 - kl_loss: 0.0839
# Epoch 39/100
# 16/16 [==============================] - 0s 24ms/step - loss: 176.3654 - reconstruction_loss: 178.0173 - kl_loss: 0.0833
# Epoch 40/100
# 16/16 [==============================] - 0s 21ms/step - loss: 169.0504 - reconstruction_loss: 169.6776 - kl_loss: 0.0832
# Epoch 41/100
# 16/16 [==============================] - 0s 22ms/step - loss: 174.2812 - reconstruction_loss: 174.9181 - kl_loss: 0.0833
# Epoch 42/100
# 16/16 [==============================] - 0s 23ms/step - loss: 179.9192 - reconstruction_loss: 174.4990 - kl_loss: 0.0835
# Epoch 43/100
# 16/16 [==============================] - 0s 24ms/step - loss: 179.1076 - reconstruction_loss: 182.0517 - kl_loss: 0.0855
# Epoch 44/100
# 16/16 [==============================] - 0s 23ms/step - loss: 171.4100 - reconstruction_loss: 171.1396 - kl_loss: 0.0856
# Epoch 45/100
# 16/16 [==============================] - 0s 23ms/step - loss: 174.5852 - reconstruction_loss: 173.3105 - kl_loss: 0.0854
# Epoch 46/100
# 16/16 [==============================] - 0s 24ms/step - loss: 170.6891 - reconstruction_loss: 169.7515 - kl_loss: 0.0850
# Epoch 47/100
# 16/16 [==============================] - 0s 23ms/step - loss: 180.9907 - reconstruction_loss: 170.8922 - kl_loss: 0.0848
# Epoch 48/100
# 16/16 [==============================] - 0s 22ms/step - loss: 171.5057 - reconstruction_loss: 173.6154 - kl_loss: 0.0832
# Epoch 49/100
# 16/16 [==============================] - 0s 23ms/step - loss: 167.8948 - reconstruction_loss: 168.4180 - kl_loss: 0.0784
# Epoch 50/100
# 16/16 [==============================] - 0s 23ms/step - loss: 167.6855 - reconstruction_loss: 170.3463 - kl_loss: 0.0776
# Epoch 51/100
# 16/16 [==============================] - 0s 23ms/step - loss: 170.9218 - reconstruction_loss: 169.1521 - kl_loss: 0.0775
# Epoch 52/100
# 16/16 [==============================] - 0s 24ms/step - loss: 167.7748 - reconstruction_loss: 170.6599 - kl_loss: 0.0775
# Epoch 53/100
# 16/16 [==============================] - 0s 24ms/step - loss: 162.3024 - reconstruction_loss: 163.8553 - kl_loss: 0.0775
# Epoch 54/100
# 16/16 [==============================] - 0s 23ms/step - loss: 161.3358 - reconstruction_loss: 163.5496 - kl_loss: 0.0775
# Epoch 55/100
# 16/16 [==============================] - 0s 25ms/step - loss: 165.1418 - reconstruction_loss: 168.2855 - kl_loss: 0.0775
# Epoch 56/100
# 16/16 [==============================] - 0s 24ms/step - loss: 164.8281 - reconstruction_loss: 165.8142 - kl_loss: 0.0774
# Epoch 57/100
# 16/16 [==============================] - 0s 24ms/step - loss: 161.0094 - reconstruction_loss: 163.6681 - kl_loss: 0.0773
# Epoch 58/100
# 16/16 [==============================] - 0s 24ms/step - loss: 162.4657 - reconstruction_loss: 164.4357 - kl_loss: 0.0771
# Epoch 59/100
# 16/16 [==============================] - 0s 24ms/step - loss: 160.6796 - reconstruction_loss: 158.9560 - kl_loss: 0.0771
# Epoch 60/100
# 16/16 [==============================] - 0s 24ms/step - loss: 160.7971 - reconstruction_loss: 161.9523 - kl_loss: 0.0771
# Epoch 61/100
# 16/16 [==============================] - 0s 24ms/step - loss: 160.8609 - reconstruction_loss: 159.9706 - kl_loss: 0.0771
# Epoch 62/100
# 16/16 [==============================] - 0s 24ms/step - loss: 157.8312 - reconstruction_loss: 157.7306 - kl_loss: 0.0772
# Epoch 63/100
# 16/16 [==============================] - 0s 24ms/step - loss: 162.7553 - reconstruction_loss: 160.2425 - kl_loss: 0.0771
# Epoch 64/100
# 16/16 [==============================] - 0s 23ms/step - loss: 165.6264 - reconstruction_loss: 161.2585 - kl_loss: 0.0772
# Epoch 65/100
# 16/16 [==============================] - 0s 22ms/step - loss: 160.3501 - reconstruction_loss: 158.6984 - kl_loss: 0.0773
# Epoch 66/100
# 16/16 [==============================] - 0s 22ms/step - loss: 162.2656 - reconstruction_loss: 163.6421 - kl_loss: 0.0773
# Epoch 67/100
# 16/16 [==============================] - 0s 23ms/step - loss: 157.8385 - reconstruction_loss: 159.1177 - kl_loss: 0.0773
# Epoch 68/100
# 16/16 [==============================] - 0s 24ms/step - loss: 155.8111 - reconstruction_loss: 161.8640 - kl_loss: 0.0770
# Epoch 69/100
# 16/16 [==============================] - 0s 23ms/step - loss: 157.9917 - reconstruction_loss: 158.4833 - kl_loss: 0.0769
# Epoch 70/100
# 16/16 [==============================] - 0s 23ms/step - loss: 158.8131 - reconstruction_loss: 157.2832 - kl_loss: 0.0769
# Epoch 71/100
# 16/16 [==============================] - 0s 24ms/step - loss: 153.9731 - reconstruction_loss: 155.3794 - kl_loss: 0.0769
# Epoch 72/100
# 16/16 [==============================] - 0s 23ms/step - loss: 154.9511 - reconstruction_loss: 156.1302 - kl_loss: 0.0769
# Epoch 73/100
# 16/16 [==============================] - 0s 23ms/step - loss: 156.2566 - reconstruction_loss: 155.5120 - kl_loss: 0.0769
# Epoch 74/100
# 16/16 [==============================] - 0s 24ms/step - loss: 158.6231 - reconstruction_loss: 155.6559 - kl_loss: 0.0768
# Epoch 75/100
# 16/16 [==============================] - 0s 23ms/step - loss: 152.6463 - reconstruction_loss: 153.8889 - kl_loss: 0.0768
# Epoch 76/100
# 16/16 [==============================] - 0s 23ms/step - loss: 153.0609 - reconstruction_loss: 153.7430 - kl_loss: 0.0768
# Epoch 77/100
# 16/16 [==============================] - 0s 23ms/step - loss: 151.7825 - reconstruction_loss: 151.7628 - kl_loss: 0.0769
# Epoch 78/100
# 16/16 [==============================] - 0s 23ms/step - loss: 153.4731 - reconstruction_loss: 152.6947 - kl_loss: 0.0769
# Epoch 79/100
# 16/16 [==============================] - 0s 23ms/step - loss: 151.3410 - reconstruction_loss: 151.9899 - kl_loss: 0.0769
# Epoch 80/100
# 16/16 [==============================] - 0s 24ms/step - loss: 153.1803 - reconstruction_loss: 155.3998 - kl_loss: 0.0769
# Epoch 81/100
# 16/16 [==============================] - 0s 23ms/step - loss: 150.3055 - reconstruction_loss: 150.2085 - kl_loss: 0.0769
# Epoch 82/100
# 16/16 [==============================] - 0s 23ms/step - loss: 153.6096 - reconstruction_loss: 152.1815 - kl_loss: 0.0769
# Epoch 83/100
# 16/16 [==============================] - 0s 24ms/step - loss: 149.5375 - reconstruction_loss: 149.8758 - kl_loss: 0.0769
# Epoch 84/100
# 16/16 [==============================] - 0s 23ms/step - loss: 150.5243 - reconstruction_loss: 149.9221 - kl_loss: 0.0769
# Epoch 85/100
# 16/16 [==============================] - 0s 24ms/step - loss: 152.4474 - reconstruction_loss: 151.9172 - kl_loss: 0.0769
# Epoch 86/100
# 16/16 [==============================] - 0s 22ms/step - loss: 151.6982 - reconstruction_loss: 153.1069 - kl_loss: 0.0769
# Epoch 87/100
# 16/16 [==============================] - 0s 23ms/step - loss: 153.8927 - reconstruction_loss: 153.8784 - kl_loss: 0.0761
# Epoch 88/100
# 16/16 [==============================] - 0s 24ms/step - loss: 149.7675 - reconstruction_loss: 150.4476 - kl_loss: 0.0760
# Epoch 89/100
# 16/16 [==============================] - 0s 24ms/step - loss: 149.0994 - reconstruction_loss: 148.4684 - kl_loss: 0.0760
# Epoch 90/100
# 16/16 [==============================] - 0s 24ms/step - loss: 149.8472 - reconstruction_loss: 149.9277 - kl_loss: 0.0760
# Epoch 91/100
# 16/16 [==============================] - 0s 24ms/step - loss: 152.5461 - reconstruction_loss: 149.3061 - kl_loss: 0.0760
# Epoch 92/100
# 16/16 [==============================] - 0s 17ms/step - loss: 148.1866 - reconstruction_loss: 148.2743 - kl_loss: 0.0760
# Epoch 93/100
# 16/16 [==============================] - 0s 24ms/step - loss: 149.2625 - reconstruction_loss: 149.2353 - kl_loss: 0.0760
# Epoch 94/100
# 16/16 [==============================] - 0s 25ms/step - loss: 148.3948 - reconstruction_loss: 149.5470 - kl_loss: 0.0760
# Epoch 95/100
# 16/16 [==============================] - 0s 24ms/step - loss: 149.3349 - reconstruction_loss: 148.4183 - kl_loss: 0.0760
# Epoch 96/100
# 16/16 [==============================] - 0s 24ms/step - loss: 151.3839 - reconstruction_loss: 149.8821 - kl_loss: 0.0760
# Epoch 97/100
# 16/16 [==============================] - 0s 24ms/step - loss: 148.1538 - reconstruction_loss: 147.1095 - kl_loss: 0.0760
# Epoch 98/100
# 16/16 [==============================] - 0s 23ms/step - loss: 146.3596 - reconstruction_loss: 146.7214 - kl_loss: 0.0760
# Epoch 99/100
# 16/16 [==============================] - 0s 24ms/step - loss: 145.3694 - reconstruction_loss: 145.4474 - kl_loss: 0.0760
# Epoch 100/100
# 16/16 [==============================] - 0s 24ms/step - loss: 147.7391 - reconstruction_loss: 148.1043 - kl_loss: 0.0760

# %%
plt.figure(figsize=(6,4))
for key in history.history.keys():
    plt.plot(history.history[key], label = key)
plt.grid()
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["reconstruction_loss"], label = "reconstruction loss")
plt.grid()
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,4))
plt.plot(history.history["kl_loss"])
plt.grid()
plt.xlabel("Epochs")
plt.ylabel("kl loss")
plt.tight_layout()
plt.show()
